# %%
import pandas as pd
import os

# %%
PATH = os.getcwd()

# %%
dfs = []
for f in os.listdir(PATH):
    f_n,f_ext = os.path.splitext(f)
    if(f_ext == ".csv"):
        dfs.append(pd.read_csv(f))
print(len(dfs))
# Out:
# 5

# %%
dfs[4]
# Out:
#                                                 Title  Ticket sales (est.)  \
# 0                                       Spirited Away             45595221
# 1                                           Your Name             44342412
# 2                            Pokémon: The First Movie             36837706
# 3   Demon Slayer: Kimetsu no Yaiba the Movie: Muge...             32963398
# 4                                 Weathering with You             22668643
# 5                                Stand by Me Doraemon             22660474
# 6                                Howl's Moving Castle             21943336
# 7                             Pokémon: The Movie 2000             19503160
# 8                                               Ponyo             18101454
# 9                            Dragon Ball Super: Broly             16227175
# 10                                  Princess Mononoke             16214830
# ...
